# %%
#SOLUTION-3
import numpy as np
import cv2 as cv 
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow # for image display
from skimage import io

#URL from where the image is downloaded
url = "https://placekitten.com/500/300"

#Reading the image from the URL
myImg = io.imread(url)  

#Open-cv reads the image in BGR format so to change it to RGB
original_img = cv.cvtColor(myImg, cv.COLOR_BGR2RGB)

#Image is showing
print("\nOriginal Image:\n")
cv2_imshow(original_img)
print("\n")

avg_0 = np.average(original_img[:, :, 0])

avg_1 = np.average(original_img[:, :, 1])

avg_2 = np.average(original_img[:, :, 2])

print("\n")
for i in range (0,dimensions[0]):
  for j in range (0,dimensions[1]):
        original_img[i,j,0]-=avg_0
        original_img[i,j,1]-=avg_1
        original_img[i,j,2]-=avg_2

print("After the Operation:\n")
cv2_imshow(original_img)
print("average Red",avg_0)
print("average Green",avg_1)
print("average Blue",avg_2)
# Out:
# Original Image:
# <PIL.Image.Image image mode=RGB size=500x300 at 0x7FBBBA4C85C0>
# After the Operation:
# <PIL.Image.Image image mode=RGB size=500x300 at 0x7FBBBA4C8780>
# average Red 99.10054
# average Green 104.67088
# average Blue 111.57052
